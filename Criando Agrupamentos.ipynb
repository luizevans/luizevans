# %% [markdown]
# # Relatórios de Análise VII

# %% [markdown]
# ## Criando Agrupamentos

# %%
import pandas as pd

# %%
dados = pd.read_csv('data/aluguel_residencial.csv', sep = ';')

# %%
dados.set_index('Unnamed: 0')
# Out:
#                    Tipo                Bairro  Quartos  Vagas  Suites  Area  \
# Unnamed: 0
# 0             Quitinete            Copacabana        1      0       0    40
# 1                  Casa       Jardim Botânico        2      0       1   100
# 2           Apartamento                Centro        1      0       0    15
# 3           Apartamento          Higienópolis        1      0       0    48
# 5           Apartamento              Cachambi        2      0       0    50
# ...                 ...                   ...      ...    ...     ...   ...
# 22575       Apartamento                 Méier        2      0       0    70
# 22576         Quitinete                Centro        0      0       0    27
# 22577       Apartamento           Jacarepaguá        3      1       2    78
# 22578       Apartamento  São Francisco Xavier        2      1       0    48
# 22579       Apartamento                Leblon        2      0       0    70
#
# ...

# %%
dados['Valor'].mean() # Media
# Out:
# 5046.172821405663

# %%
dados.Bairro.unique()
# Out:
# array(['Copacabana', 'Jardim Botânico', 'Centro', 'Higienópolis',
#        'Cachambi', 'Barra da Tijuca', 'Ramos', 'Grajaú',
#        'Lins de Vasconcelos', 'Taquara', 'Freguesia (Jacarepaguá)',
#        'Tijuca', 'Olaria', 'Ipanema', 'Campo Grande', 'Botafogo',
#        'Recreio dos Bandeirantes', 'Leblon', 'Jardim Oceânico', 'Humaitá',
#        'Península', 'Méier', 'Vargem Pequena', 'Maracanã', 'Jacarepaguá',
#        'São Conrado', 'Vila Valqueire', 'Gávea', 'Cosme Velho',
#        'Bonsucesso', 'Todos os Santos', 'Laranjeiras', 'Itanhangá',
#        'Flamengo', 'Piedade', 'Lagoa', 'Catete', 'Jardim Carioca',
#        'Benfica', 'Glória', 'Praça Seca', 'Vila Isabel', 'Engenho Novo',
#        'Engenho de Dentro', 'Pilares', 'Água Santa', 'São Cristóvão',
#        'Ilha do Governador', 'Jardim Sulacap', 'Oswaldo Cruz',
#        'Vila da Penha', 'Anil', 'Vargem Grande', 'Tanque', 'Vaz Lobo',
#        'Madureira', 'São Francisco Xavier', 'Pechincha', 'Leme', 'Irajá',
# ...

# %%
bairros = ['Copacabana', 'Jardim Botânico', 'Centro', 'Higienópolis',
       'Cachambi', 'Barra da Tijuca', 'Ramos', 'Grajaú',
       'Lins de Vasconcelos', 'Taquara', 'Freguesia (Jacarepaguá)',
       'Tijuca', 'Olaria', 'Ipanema']

# %%
selecao = dados['Bairro'].isin(bairros)
dados = dados[selecao]

# %%
dados.Bairro.value_counts()
# Out:
# Barra da Tijuca            3863
# Copacabana                 2644
# Ipanema                    1764
# Tijuca                     1100
# Freguesia (Jacarepaguá)     456
# Centro                      343
# Jardim Botânico             263
# Taquara                     171
# Grajaú                      145
# Cachambi                    132
# Lins de Vasconcelos          47
# Ramos                        35
# Olaria                       32
# Higienópolis                 16
# Name: Bairro, dtype: int64

# %%
grupo_bairro = dados.groupby('Bairro')

# %%
type(grupo_bairro)
# Out:
# pandas.core.groupby.generic.DataFrameGroupBy

# %%
grupo_bairro.groups
# Out:
# {'Barra da Tijuca': [5, 14, 16, 21, 30, 32, 35, 42, 43, 60, 61, 64, 68, 74, 79, 93, 107, 110, 112, 117, 130, 132, 136, 150, 153, 155, 165, 166, 173, 186, 189, 207, 214, 221, 224, 233, 236, 239, 244, 259, 265, 274, 276, 291, 292, 293, 295, 302, 308, 311, 325, 335, 336, 345, 360, 366, 368, 374, 380, 387, 389, 400, 412, 432, 433, 435, 436, 439, 449, 451, 462, 463, 465, 473, 476, 484, 494, 500, 503, 511, 537, 538, 539, 540, 543, 547, 552, 554, 555, 556, 584, 587, 588, 590, 594, 596, 601, 611, 622, 630, ...], 'Cachambi': [4, 56, 247, 252, 525, 629, 1389, 1683, 1862, 1949, 2087, 2178, 2556, 2633, 2889, 3009, 3045, 3080, 3755, 4060, 4161, 4195, 4204, 4398, 4446, 4635, 4638, 5272, 5280, 5292, 5308, 5455, 5523, 5572, 5749, 5862, 5919, 5987, 5996, 6173, 6176, 6239, 6378, 6386, 6485, 6600, 6771, 6832, 6850, 7315, 7423, 7441, 7625, 7737, 7907, 8014, 8046, 8066, 8200, 8217, 8600, 8685, 8896, 8904, 8944, 9119, 9123, 9232, 9476, 9578, 9582, 9682, 9855, 10187, 10194, 10353, 10783, 10813, 11075, 1109
# ...

# %%
for bairro, dado in grupo_bairro:
    print(f'{bairro} -> {dado.Valor.mean()}') # Média de valor pra cada bairro
# Out:
# Barra da Tijuca -> 7069.552938130986
# Cachambi -> 1157.1742424242425
# Centro -> 1254.7521865889212
# Copacabana -> 4126.677004538578
# Freguesia (Jacarepaguá) -> 4966.666666666667
# Grajaú -> 2038.6206896551723
# Higienópolis -> 1006.25
# Ipanema -> 9352.001133786847
# Jardim Botânico -> 8722.357414448668
# Lins de Vasconcelos -> 1086.1702127659576
# Olaria -> 1016.5625
# Ramos -> 958.0
# Taquara -> 1642.140350877193
# Tijuca -> 2043.52

# %%
grupo_bairro[['Valor', 'Condominio']].mean().round(2) # Média de forma rápida e criação de DataFrame
# Out:
#                            Valor  Condominio
# Bairro
# Barra da Tijuca          7069.55     3591.01
# Cachambi                 1157.17      452.77
# Centro                   1254.75      422.57
# Copacabana               4126.68     1148.68
# Freguesia (Jacarepaguá)  4966.67      701.47
# Grajaú                   2038.62      575.02
# Higienópolis             1006.25      185.50
# Ipanema                  9352.00     2244.44
# Jardim Botânico          8722.36     1059.24
# Lins de Vasconcelos      1086.17    11502.60
# Olaria                   1016.56      263.50
# Ramos                     958.00      112.83
# Taquara                  1642.14      411.53
# Tijuca                   2043.52      711.69

# %% [markdown]
# # Desafio Alura

# %%
alunos = pd.DataFrame({'Nome': ['Ary', 'Cátia', 'Denis', 'Beto', 'Bruna', 'Dara', 'Carlos', 'Alice'], 
                        'Sexo': ['M', 'F', 'M', 'M', 'F', 'F', 'M', 'F'], 
                        'Idade': [15, 27, 56, 32, 42, 21, 19, 35], 
                        'Notas': [7.5, 2.5, 5.0, 10, 8.2, 7, 6, 5.6], 
                        'Aprovado': [True, False, False, True, True, True, False, False]}, 
                        columns = ['Nome', 'Idade', 'Sexo', 'Notas', 'Aprovado'])

# %%
sexo = alunos.groupby('Sexo')
sexo = pd.DataFrame(sexo['Notas'].mean().round(2))
sexo.columns = ['Notas Médias']
sexo
# Out:
#       Notas Médias
# Sexo
# F             5.82
# M             7.12

# %% [markdown]
# ## Estatísticas Descritivas

# %%
grupo_bairro['Valor'].describe().round(2)
# Out:
#                           count     mean       std     min     25%     50%  \
# Bairro
# Barra da Tijuca          3863.0  7069.55  11874.15   800.0  2500.0  4500.0
# Cachambi                  132.0  1157.17    351.49   600.0   900.0  1100.0
# Centro                    343.0  1254.75    884.67   400.0   800.0  1000.0
# Copacabana               2644.0  4126.68   3611.41   100.0  2000.0  3000.0
# Freguesia (Jacarepaguá)   456.0  4966.67  45313.69   500.0  1300.0  1700.0
# Grajaú                    145.0  2038.62   4901.99   650.0  1250.0  1500.0
# Higienópolis               16.0  1006.25    409.42   700.0   800.0   875.0
# Ipanema                  1764.0  9352.00   8219.72  1200.0  4500.0  7000.0
# Jardim Botânico           263.0  8722.36   9332.73  1550.0  3150.0  4000.0
# Lins de Vasconcelos        47.0  1086.17    439.58   500.0   850.0  1000.0
# Olaria                     32.0  1016.56    272.13   660.0   800.0  1000.0
# ...

# %%
grupo_bairro['Valor'].aggregate(['min', 'max']).rename(columns = {'min': 'Mínimo', 'max': 'Máximo'}) # seleção de estatisticas
# Out:
#                          Mínimo    Máximo
# Bairro
# Barra da Tijuca           800.0  600000.0
# Cachambi                  600.0    2800.0
# Centro                    400.0   12000.0
# Copacabana                100.0   35000.0
# Freguesia (Jacarepaguá)   500.0  800000.0
# Grajaú                    650.0   60000.0
# Higienópolis              700.0    2400.0
# Ipanema                  1200.0   90000.0
# Jardim Botânico          1550.0   50000.0
# Lins de Vasconcelos       500.0    2800.0
# Olaria                    660.0    1700.0
# Ramos                     500.0    1700.0
# Taquara                   500.0   10000.0
# Tijuca                    750.0   45000.0

# %% [markdown]
# ## Iniciando no MatplotLib

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.rc('figure', figsize = (20, 10))

# %%
fig = grupo_bairro['Valor'].mean().plot.bar(color = 'blue')
fig.set_ylabel('Valor do Aluguel')
fig.set_title('Valor Médio do Aluguel por Bairro', {'fontsize': 22})
# Out:
# Text(0.5, 1.0, 'Valor Médio do Aluguel por Bairro')

# %%
fig_1 = grupo_bairro['Quartos'].mean().plot.bar(color = 'green')
fig_1.set_ylabel('Qntd de Quartos')
fig_1.set_title('Médio de nº de Quarto', {'fontsize': 22})
# Out:
# Text(0.5, 1.0, 'Médio de nº de Quarto')

# %%
fig_2 = grupo_bairro['Condominio'].mean().plot.bar(color = 'red')
fig_2.set_ylabel('Qntd de Condominio')
fig_2.set_title('Valor médio do Condominio', {'fontsize': 22})
# Out:
# Text(0.5, 1.0, 'Valor médio do Condominio')

# %%
fig_3 = grupo_bairro['IPTU'].mean().plot.bar(color = 'Grey')
fig_3.set_ylabel('Nº de IPTU')
fig_3.set_title('Valor médio do IPTU', {'fontsize': 22})
# Out:
# Text(0.5, 1.0, 'Valor médio do IPTU')

# %%
fig_4 = grupo_bairro['Area'].mean().plot.bar(color = 'blue')
fig_4.set_ylabel('Qtde de Area')
fig_4.set_title('Tamanho médio da Area', {'fontsize': 22})
# Out:
# Text(0.5, 1.0, 'Tamanho médio da Area')

# %% [markdown]
# ## Desafio Alura

# %%
precos = pd.DataFrame([['Feira', 'Cebola', 2.5], 
                        ['Mercado', 'Cebola', 1.99], 
                        ['Supermercado', 'Cebola', 1.69], 
                        ['Feira', 'Tomate', 4], 
                        ['Mercado', 'Tomate', 3.29], 
                        ['Supermercado', 'Tomate', 2.99], 
                        ['Feira', 'Batata', 4.2], 
                        ['Mercado', 'Batata', 3.99], 
                        ['Supermercado', 'Batata', 3.69]], 
                        columns = ['Local', 'Produto', 'Preço'])
precos
# Out:
#           Local Produto  Preço
# 0         Feira  Cebola   2.50
# 1       Mercado  Cebola   1.99
# 2  Supermercado  Cebola   1.69
# 3         Feira  Tomate   4.00
# 4       Mercado  Tomate   3.29
# 5  Supermercado  Tomate   2.99
# 6         Feira  Batata   4.20
# 7       Mercado  Batata   3.99
# 8  Supermercado  Batata   3.69

# %%
produtos = precos.groupby('Produto', sort = False)
produtos.describe().round(2)
# Out:
#         Preço
#         count  mean   std   min   25%   50%   75%  max
# Produto
# Cebola    3.0  2.06  0.41  1.69  1.84  1.99  2.24  2.5
# Tomate    3.0  3.43  0.52  2.99  3.14  3.29  3.64  4.0
# Batata    3.0  3.96  0.26  3.69  3.84  3.99  4.10  4.2

# %%
produtos['Preço'].aggregate(['mean', 'std', 'min', 'max']).rename(columns = {'mean': 'Média', 'std': 'Desvio Padrão','min': 'Mínimo', 'max': 'Máximo'}).round(2)
# Out:
#          Média  Desvio Padrão  Mínimo  Máximo
# Produto
# Cebola    2.06           0.41    1.69     2.5
# Tomate    3.43           0.52    2.99     4.0
# Batata    3.96           0.26    3.69     4.2

# %%
estatisticas = ['mean', 'std', 'min', 'max']
nomes = {'mean': 'Média', 'std': 'Desvio Padrão', 
    'min': 'Mínimo', 'max': 'Máximo'}
produtos['Preço'].aggregate(estatisticas).rename(columns = nomes).round(2)
# Out:
#          Média  Desvio Padrão  Mínimo  Máximo
# Produto
# Cebola    2.06           0.41    1.69     2.5
# Tomate    3.43           0.52    2.99     4.0
# Batata    3.96           0.26    3.69     4.2
